# %%
import Transformations
# Out:
# (548, 768, 3)
# (1684, 1800, 3)

# %%
Transformations.Crop("logo_fondo.png")

# %%
Transformations.Rotate1("logo_fondo.png")

# %%
Transformations.hsv_new("logo_fondo.png")

# %%
Transformations.Circle("logo_fondo.png")

# %%
Transformations.HSV("logo_fondo.png")

# %%
Transformations.Circle("logo_fondo.png")
